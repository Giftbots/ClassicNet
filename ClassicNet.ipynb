# %%
from fastai.vision.all import *
from fastai.vision.widgets import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d2d29be66561> in <module>()
# ----> 1 from fastai.vision.all import *
#       2 from fastai.vision.widgets import *
#
# ModuleNotFoundError: No module named 'fastai.vision.all'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # **ShipNet v1.0**

# %% [markdown]
# **Instructions**
#
# 1. Upload an image of a ship with the 'Upload' button.
# 2. Classify the type of ship with the 'Classify' button.
# 3. Repeat until fully satisfied.

# %%
path = Path()
learn_inf = load_learner(path/'ClassicNet.pkl', cpu=True)
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
lbl_pred = widgets.Label()
btn_run = widgets.Button(description='Classify')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bc581bc770ce> in <module>()
# ----> 1 path = Path()
#       2 learn_inf = load_learner(path/'ClassicNet.pkl', cpu=True)
#       3 btn_upload = widgets.FileUpload()
#       4 out_pl = widgets.Output()
#       5 lbl_pred = widgets.Label()
#
# NameError: name 'Path' is not defined

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    if pred == 'Parthenon':
      pred = 'Parthenon'
    if pred == 'Pyramids':
      pred = 'Pyramid'
    if pred == 'Colosseum':
      pred = 'Colosseum'
    confidence_level = round((float(probs[pred_idx]) * 100), 2)
    lbl_pred.value = f'Prediction: {pred}; Confidence level: {confidence_level}%'
    btn_upload.value.clear()
    btn_upload._counter = 0

btn_run.on_click(on_click_classify)

# %%
VBox([widgets.Label('Upload your classical monument image'), 
      btn_upload, btn_run, out_pl, lbl_pred])

# %% [markdown]
# # **Introducing ClassicNet**
# ## **The world's first and only classical architecture detection algorithm**
#
# We students of classical antiquity are all familiar with the beauty and magnificence of ancient architecture. However, with the multitude of classical monuments in the world, how are we to remember the names and forms of the great monuments of the past? How are we to distinguish between, the Parthenon, the Pyramids, and the Colosseum?
#
# If you've ever asked a question like this, you're in luck! With ClassicNet, such problems are a things of the past. At UselessAI.ai, we bring our deep learning expertise to solve this previously intractable problem. With our algorithm, you (yes, even you!) can identify 3 great examples of classical monumental architecture with ease. Simply upload an image of the Parthenon, the Pyramids of Giza, or the Colosseum, and ClassicNet will identify its name!
#
# Remember: **Never take a picture without ClassicNet - your true classicist friend**
#
# Note: ClassicNet may not accurately classify with 100% accuracy
#
# Note^2: Please do not abuse ClassicNet with images that do not contain the Parthenon, Pyramids or Colosseum - it has feelings too.
